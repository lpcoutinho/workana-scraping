# %%
# import libs
import pandas as pd
import time

from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException

# %%
# init session
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# maximizing browser window
driver.maximize_window()

# %%
# list to store datas for dataframe
data = []

# list to store performance data
perf = []

# to check script performance
start_time = time.time()
print("Iniciando raspagem de dados no Workana\n")

# iterating through the pages - usually 50 pages
for p in range(1, 51):
    # to check script performance
    start_loop = time.time()

    # go to jobs
    driver.get(f"https://www.workana.com/jobs?language=pt&page={p}")

    print(f"https://www.workana.com/jobs?language=pt&page={p}")

    # wait
    time.sleep(2)

    # iterating through the objects
    for i in range(2, 11):
        try:
            job_title = driver.find_element(
                By.XPATH, f'//*[@id="projects"]/div[{i}]/div[1]/h2/a/span'
            )
            job_title = job_title.get_attribute("title")
        except NoSuchElementException:
            job_title = f"Erro no título {i} da página{p}"
            print(f"Erro em job_title {i} da p{p}")

        try:
            job_date = driver.find_element(
                By.XPATH, f'//*[@id="projects"]/div[{i}]/div[1]/h5'
            )
            job_date = job_date.get_attribute("title")
        except NoSuchElementException:
            job_date = f"Erro na data {i} da página{p}"
            print(f"Erro em job_date {i} da p{p}")

        try:
            job_link = driver.find_element(
                By.XPATH, f'//*[@id="projects"]/div[{i}]/div[1]/h2/a'
            )
            job_link = job_link.get_attribute("href")
        except NoSuchElementException:
            job_link = f"Erro no link {i} da página{p}"
            print(f"Erro em job_link {i} da p{p}")

        try:
            job_bids = driver.find_element(
                By.XPATH, f'//*[@id="projects"]/div[{i}]/div[2]/div[1]/span[2]'
            )
            job_bids = job_bids.text.split(" ")[1]
        except NoSuchElementException:
            job_bids = f"Erro no orçamento {i} da página{p}"
            print(f"Erro em job_bids {i} da p{p}")

        try:
            job_budget = driver.find_element(
                By.XPATH, f'//*[@id="projects"]/div[{i}]/div[3]/h4/span'
            )
            job_budget = job_budget.text
        except NoSuchElementException:
            job_budget = f"Erro no budget {i} da página{p}"
            print(f"Erro em job_budget {i} da p{p}")

        try:
            see_more = driver.find_element(
                By.XPATH, f'//*[@id="projects"]/div[{i}]/div[2]/div[2]/div/span[2]'
            )
            if see_more.is_displayed():
                job_desc = driver.find_element(
                    By.XPATH, f'//*[@id="projects"]/div[3]/div[2]/div[2]/div'
                )
                job_desc_more = driver.find_element(
                    By.XPATH, f'//*[@id="projects"]/div[3]/div[2]/div[2]/div/span[2]'
                )
                job_desc = job_desc.text + job_desc_more.text
        except NoSuchElementException:
            job_desc = f"Erro no job_desc {i} da página{p}"
            print(f"Erro em job_desc {i} da p{p}")

        # get job skills
        job_sk = []

        try:
            skills = driver.find_element(
                By.XPATH, f'//*[@id="projects"]/div[{i}]/div[2]/div[3]/div'
            )
            skills = skills.find_elements(By.TAG_NAME, "a")

            for skill in skills:
                job_sk.append(skill.text)

            job_sk = ", ".join(job_sk)
        except NoSuchElementException:
            print(f"Erro em skills {i} da p{p}")
            job_sk.append("N/I")

        # create data list
        data_tmp = {
            "Job": job_title,
            "Publish Date": job_date,
            "Skills": job_sk,
            "Budget": job_budget,
            "Bids": job_bids,
            "Summary": job_desc,
            "Link": job_link,
        }

        data.append(data_tmp)

    # to check script performance
    end_loop = time.time()
    duration_loop = end_loop - start_loop
    print(f"Página {p} levou {duration_loop} segundos para ser carregada\n")

    # create performance list
    perf_tmp = {"#Loop": {p}, "End Loop": duration_loop}
    perf.append(perf_tmp)

# to analysis script performance
end_time = time.time()
duration_t_s = end_time - start_time
duration_t_m = duration_t_s / 60
print(f"O tempo total para raspar os dados foi de {duration_t_m} minutos\n")
# Out:
# Iniciando raspagem de dados no Workana
#
# https://www.workana.com/jobs?language=pt&page=1
# Página 1 levou 6.893089294433594 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=2
# Página 2 levou 5.0935540199279785 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=3
# Página 3 levou 4.605372905731201 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=4
# Página 4 levou 4.554448843002319 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=5
# Página 5 levou 5.112185478210449 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=6
# Página 6 levou 5.506776571273804 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=7
# Página 7 levou 5.416611433029175 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=8
# Erro em skills 6 da p8
# Página 8 levou 5.46797251701355 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=9
# Página 9 levou 5.000664710998535 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=10
# Página 10 levou 5.06562352180481 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=11
# Erro em skills 6 da p11
# Página 11 levou 4.715497016906738 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=12
# Erro em skills 6 da p12
# Página 12 levou 4.904874563217163 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=13
# Página 13 levou 4.726127624511719 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=14
# Página 14 levou 4.718770980834961 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=15
# Página 15 levou 4.947730541229248 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=16
# Erro em skills 7 da p16
# Página 16 levou 6.381551027297974 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=17
# Página 17 levou 4.391400337219238 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=18
# Página 18 levou 4.828486442565918 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=19
# Página 19 levou 5.025602579116821 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=20
# Página 20 levou 4.534865617752075 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=21
# Página 21 levou 4.649581670761108 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=22
# Página 22 levou 4.652094602584839 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=23
# Página 23 levou 5.703563690185547 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=24
# Página 24 levou 4.756628751754761 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=25
# Página 25 levou 4.911803245544434 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=26
# Erro em skills 5 da p26
# Erro em skills 9 da p26
# Página 26 levou 4.500789642333984 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=27
# Página 27 levou 4.605163812637329 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=28
# Página 28 levou 4.495354413986206 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=29
# Página 29 levou 4.917138338088989 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=30
# Página 30 levou 4.609714984893799 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=31
# Página 31 levou 4.907829999923706 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=32
# Página 32 levou 4.745250701904297 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=33
# Página 33 levou 4.901305198669434 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=34
# Página 34 levou 4.6128692626953125 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=35
# Erro em skills 6 da p35
# Página 35 levou 4.9199607372283936 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=36
# Erro em skills 4 da p36
# Erro em skills 7 da p36
# Página 36 levou 4.61527681350708 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=37
# Página 37 levou 4.6380615234375 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=38
# Página 38 levou 5.059245347976685 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=39
# Página 39 levou 4.79203724861145 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=40
# Erro em skills 9 da p40
# Página 40 levou 4.682049989700317 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=41
# Erro em skills 9 da p41
# Página 41 levou 4.861322402954102 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=42
# Página 42 levou 4.480189323425293 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=43
# Página 43 levou 4.699683904647827 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=44
# Erro em skills 4 da p44
# Página 44 levou 4.921109199523926 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=45
# Página 45 levou 4.658625602722168 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=46
# Página 46 levou 4.916203260421753 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=47
# Erro em skills 6 da p47
# Página 47 levou 4.588816404342651 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=48
# Página 48 levou 5.0544610023498535 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=49
# Página 49 levou 4.99822211265564 segundos para ser carregada
#
# https://www.workana.com/jobs?language=pt&page=50
# Página 50 levou 5.039669990539551 segundos para ser carregada
#
# O tempo total para raspar os dados foi de 4.096504966417949 minutos

# %%
len(data)
# Out:
# 450

# %%
print("Titilo:", job_title)
print("Publicação:", job_date)
print(job_desc)
print(job_link)
print("Propostas:", job_bids)
print("Valor:", job_budget)
print("Skills:", job_sk)
# Out:
# Titilo: Estrategia de marketing e funil de vendas
# Publicação: 09 de Maio de 2023 13:41
# Preciso de estratégia de marketing e funil de vendas de um produto de emagrecimento, produto novo, com nome novo. Um desafio Para um bom trabalho de marketing digital.
#
# Categoria: Marketing e Vendas
# Subcategoria: Outros
# Tamanho do projeto: Pequeño
# Isso é um projeto ou uma posição de trabalho?: Um... Ver mais detalhes
# https://www.workana.com/job/estrategia-de-marketing-e-funil-de-vendas?ref=projects_50
# Propostas: 6
# Valor: Menos de USD 50
# Skills: Facebook, Marketing Online, Marketing, Escrita criativa, Design Gráfico, +

# %%
# create sracapp dataframe
df_raw = pd.DataFrame(data)
df_raw.head(1)
# Out:
#                                                  Job
# 0  Desenvolvimento de Ferramenta Para Checkout We...  \
#
#                Publish Date                   Skills             Budget Bids
# 0  11 de Maio de 2023 12:50  Magento, PHP, WordPress  USD 1.000 - 3.000    1  \
#
#                                              Summary
# 0  Procuro dev full stack para projeto de desenvo...  \
#
#                                                 Link
# 0  https://www.workana.com/job/desenvolvimento-de...

# %%
# create performance dataframe
df_perf = pd.DataFrame(perf)
df_perf["Init Script"] = start_time
df_perf["End Script"] = end_time
df_perf.head(1)
# Out:
#   #Loop  End Loop   Init Script    End Script
# 0   {1}  6.893089  1.683815e+09  1.683815e+09

# %% [markdown]
# # Export data

# %%
# create csv
df_raw.to_csv("../workana_scraping/data/data_raw.csv", index=False)
df_perf.to_csv("../workana_scraping/data/performance/performance.csv", index=False)
